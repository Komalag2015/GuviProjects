# %%
import pandas as pd
from faker import Faker
import datetime
import random
from faker.providers import DynamicProvider


class BaseDataGenerator:
    def __init__(self, records):
        self.records = records
        self.fake = Faker('en_IN')

''' *************** Create DataFrame for Table Students ************** '''

class StudentGenerator(BaseDataGenerator):
    def generate_students(self):
        students = []
        for i in range(1, self.records + 1):
            name = self.fake.name()
            enrollment_year = random.randint(2015, 2024)
            graduation_year = random.randint(enrollment_year, enrollment_year + 5)
            students.append({
                "student_id": i,
                "Name": name,
                "Age": random.randint(15, 50),
                "Gender": random.choice(['Male', 'Female', 'Other']),
                "Email": name.lower().replace(' ', '.') + '@fake_domain-2.com',
                "phone": self.fake.phone_number(),
                "enrollment_year": enrollment_year,
                "course_batch": random.choice(['Batch1', 'Batch2', 'Batch3', 'Batch4', 'Batch5', 'Batch6', 'Batch7']),
                "City": self.fake.city(),
                "graduation_year": graduation_year
            })
        return pd.DataFrame(students)

''' *************** Create DataFrame for Table Programming ************** '''

class ProgramGenerator(BaseDataGenerator):
    def __init__(self, records, student_ids):
        super().__init__(records)
        self.student_ids = student_ids

    def generate_program(self):
        skills_provider = DynamicProvider(
            provider_name="skills",
            elements=["Python", "Pandas", "Linux", "SQL", "Data Mining", "Java", "C", "C#", "JavaScript"],
        )
        self.fake.add_provider(skills_provider)

        program_data = []
        for i in range(1,self.records+1):
            problems_solved = random.randint(0, 150)
            assessments_completed = random.randint(0, 30)
            mini_projects = random.randint(0, 30)
            certifications_earned = random.randint(0, 30)
            total_score = problems_solved + assessments_completed + mini_projects + certifications_earned

            program_data.append({
                "programming_id": self.fake.uuid4(),
                "student_id": i,
                "language": self.fake.skills(),
                "problems_solved": problems_solved,
                "assessments_completed": assessments_completed,
                "mini_projects": mini_projects,
                "certifications_earned": certifications_earned,
                "latest_project_score": total_score
            })
        return pd.DataFrame(program_data)

''' *************** Create DataFrame for Table SoftSkills ************** '''

class SkillGenerator(BaseDataGenerator):
    def __init__(self, records, student_ids):
        super().__init__(records)
        self.student_ids = student_ids

    def generate_skills(self):
        skills_data = []
        for i in range(1,self.records+1):
            skills_data.append({
                "soft_skill_id": self.fake.uuid4(),
                "student_id": i,
                "communication": random.randint(0, 100),
                "teamwork": random.randint(0, 100),
                "presentation": random.randint(0, 100),
                "leadership": random.randint(0, 100),
                "critical_thinking": random.randint(0, 100),
                "interpersonal_skills": random.randint(0, 100)
            })
        return pd.DataFrame(skills_data)

''' *************** Create DataFrame for Table Placement ************** '''

class PlacementGenerator(BaseDataGenerator):
    def __init__(self, records, student_ids):
        super().__init__(records)
        self.student_ids = student_ids   
  
    
    def fake_data_generate_placement(self):
        
        company_provider = DynamicProvider(
            provider_name="company",
            elements=["CTS", "TCS", "WIPRO", "INFOSYS", "Amazon", "HCL ", "Capgemini", "IBM", "Accenture"],
        )        
        self.fake.add_provider(company_provider)   
        placement = []

        for i in range(1,self.records+1):
            placement.append({
                    "placement_id" : self.fake.uuid4(),
                    "student_id" : i,
                    "mock_interview_score" : random.randint(0,100),
                    "internships_completed" : random.randint(0,20),
                    "placement_status" : random.choice(['Ready','Not Ready','Placed']),
                    "interview_rounds_cleared" :  random.randint(0,20)
                    })
                          
        return pd.DataFrame(placement)       
        
''' *************** Create DataFrame Only for the students placed ************** '''
                                
    def add_placement_date(self,status):
            if status =='Placed':
                return {
                    "company_name" : self.fake.company(),
                    "placement_package":f"$ {random.randint(20000,50000)}",
                    "placement_date":self.fake.date_time_between(start_date='-5y', end_date='now'),
                    }
                                    
            else: 
                return {
                    "company_name" : None,
                    "placement_package":None,
                    "placement_date":None
                    }

''' *************** Join 2  DataFrames for Table Placement ************** '''

    def generate_placement_dataframe(self):
            placement_df1 = self.fake_data_generate_placement()
            placement_df2 = placement_df1["placement_status"].apply(self.add_placement_date).apply(pd.Series)
            finaldf = pd.concat([placement_df1,placement_df2], axis=1)
            return finaldf


class FakeDataPlacement:
    def __init__(self, records):
        self.records = records

        # Step 1: Generate Students
        self.students_df = StudentGenerator(records).generate_students()
        self.student_ids = self.students_df['student_id'].tolist()

        # Step 2–4: Other data (based on student IDs)
        self.programming_df = ProgramGenerator(records, self.student_ids).generate_program()
        self.skills_df = SkillGenerator(records, self.student_ids).generate_skills()
        self.placement_df = PlacementGenerator(records, self.student_ids).generate_placement_dataframe()

    def get_datasets(self):
        return {
            "students": self.students_df,
            "programming": self.programming_df,
            "softskills": self.skills_df,
            "placements": self.placement_df
        }

    def preview(self):
        return {
            "students": self.students_df.head(),
            "programming": self.programming_df.head(),
            "softskills": self.skills_df.head(),
            "placements": self.placement_df.head()
        }


fx = FakeDataPlacement(50)
data = fx.get_datasets()

# Preview each
for name, df in fx.preview().items():
    print(f"\n{name.upper()} DATA:")
    print(df)
# Out:
# {'students':     student_id                Name  Age  Gender  \
# 0            1    Banjeet Upadhyay   30   Other
# 1            2       Daniel Varkey   49  Female
# 2            3          Ayaan Tata   15   Other
# 3            4        Nisha Thaker   37  Female
# 4            5        Tanmayi Gala   37   Other
# 5            6         Wishi Nagar   47   Other
# 6            7        Advik Sahota   21    Male
# 7            8          Viraj Tata   50  Female
# 8            9     Onkar Venkatesh   23  Female
# 9           10  Pushti Ranganathan   18   Other
# 10          11        Mugdha Mahal   22    Male
# 11          12      Bina Kuruvilla   21   Other
# 12          13           Falak Ram   35  Female
# 13          14         Umang Saran   31  Female
# 14          15       Farhan Oommen   32  Female
# 15          16      Kashish Mannan   30  Female
# 16          17    Lopa Ranganathan   41    Male
# 17          18        Quincy Uppal   24    Male
# 18          19        Sanya Sarkar   23  Female
# 19          20       Sathvik Kunda   19    Male
# 20          21         Ekani Borra   38  Female
# 21          22       Akshay Tailor   15  Female
# 22          23          Arjun Dhar   47  Female
# 23          24        Gaurang Gill   43    Male
# 24          25          Ekapad Pai   21  Female
# 25          26        Vihaan Barad   23   Other
# 26          27     Aditya Srinivas   20   Other
# 27          28        Lohit Sarraf   20    Male
# 28          29        Lavanya Nori   24    Male
# 29          30        Azad Dhingra   23    Male
# 30          31          Ikbal Peri   45  Female
# 31          32        Manthan Buch   19   Other
# 32          33          Abhiram Om   43   Other
# 33          34       Jonathan Iyer   18   Other
# 34          35        Raagini Jain   45   Other
# 35          36       Theodore Deep   36  Female
# 36          37         Lekha Wagle   48    Male
# 37          38        Aarna Sarraf   50   Other
# 38          39      Urishilla Kota   20   Other
# 39          40         Gunbir Toor   33    Male
# 40          41            Eta Keer   27  Female
# 41          42    Nimrat Nagarajan   19   Other
# 42          43        Anusha Magar   42    Male
# 43          44         Isaac Bajwa   35   Other
# 44          45         Qarin Vohra   30   Other
# 45          46  Finn Krishnamurthy   35    Male
# 46          47        Unnati Sarna   44   Other
# 47          48         Manan Ghosh   41  Female
# 48          49        Mohini Wagle   17    Male
# 49          50     Jairaj Deshmukh   36   Other
#
#                                    Email          phone  enrollment_year  \
# 0     banjeet.upadhyay@fake_domain-2.com     3877176620             2015
# 1        daniel.varkey@fake_domain-2.com  +914209731765             2022
# 2           ayaan.tata@fake_domain-2.com    06050832317             2015
# 3         nisha.thaker@fake_domain-2.com     7837984620             2023
# 4         tanmayi.gala@fake_domain-2.com     3289041295             2022
# 5          wishi.nagar@fake_domain-2.com     9123820975             2016
# 6         advik.sahota@fake_domain-2.com  +918104533882             2019
# 7           viraj.tata@fake_domain-2.com     5211627912             2019
# 8      onkar.venkatesh@fake_domain-2.com     2769541876             2019
# 9   pushti.ranganathan@fake_domain-2.com    03681858556             2020
# 10        mugdha.mahal@fake_domain-2.com  +916358166609             2020
# 11      bina.kuruvilla@fake_domain-2.com  +918568582136             2018
# 12           falak.ram@fake_domain-2.com  +911597829410             2022
# 13         umang.saran@fake_domain-2.com  +917882589171             2015
# 14       farhan.oommen@fake_domain-2.com  +916096270268             2022
# 15      kashish.mannan@fake_domain-2.com     7655252748             2018
# 16    lopa.ranganathan@fake_domain-2.com     1481360509             2022
# 17        quincy.uppal@fake_domain-2.com     4061279650             2021
# 18        sanya.sarkar@fake_domain-2.com  +913636200760             2022
# 19       sathvik.kunda@fake_domain-2.com     9155833969             2021
# 20         ekani.borra@fake_domain-2.com     7577712364             2023
# 21       akshay.tailor@fake_domain-2.com    08047660881             2018
# 22          arjun.dhar@fake_domain-2.com  +915578214932             2017
# 23        gaurang.gill@fake_domain-2.com  +914835150000             2017
# 24          ekapad.pai@fake_domain-2.com    09062639897             2021
# 25        vihaan.barad@fake_domain-2.com     5436951450             2023
# 26     aditya.srinivas@fake_domain-2.com  +919121923718             2015
# 27        lohit.sarraf@fake_domain-2.com     1194244329             2020
# 28        lavanya.nori@fake_domain-2.com  +910745257652             2015
# 29        azad.dhingra@fake_domain-2.com     2132128978             2015
# 30          ikbal.peri@fake_domain-2.com  +918074255300             2023
# 31        manthan.buch@fake_domain-2.com    05983673823             2016
# 32          abhiram.om@fake_domain-2.com     0696224313             2023
# 33       jonathan.iyer@fake_domain-2.com    05705235014             2016
# 34        raagini.jain@fake_domain-2.com     7001307878             2019
# 35       theodore.deep@fake_domain-2.com  +917481433951             2024
# 36         lekha.wagle@fake_domain-2.com    06655958236             2022
# 37        aarna.sarraf@fake_domain-2.com    04134840296             2018
# 38      urishilla.kota@fake_domain-2.com     9639386620             2016
# 39         gunbir.toor@fake_domain-2.com  +915369561828             2016
# 40            eta.keer@fake_domain-2.com    06094669493             2024
# 41    nimrat.nagarajan@fake_domain-2.com     3337267898             2022
# 42        anusha.magar@fake_domain-2.com    04956429994             2019
# 43         isaac.bajwa@fake_domain-2.com    07180637437             2024
# 44         qarin.vohra@fake_domain-2.com     3920344398             2015
# 45  finn.krishnamurthy@fake_domain-2.com    05322011302             2017
# 46        unnati.sarna@fake_domain-2.com    05506553429             2023
# 47         manan.ghosh@fake_domain-2.com     3372917245             2017
# 48        mohini.wagle@fake_domain-2.com  +914708935372             2017
# 49     jairaj.deshmukh@fake_domain-2.com     0681098809             2021
#
#    course_batch                          City  graduation_year
# 0        Batch7                      Bahraich             2019
# 1        Batch5                    Ramagundam             2027
# 2        Batch3                        Amroha             2016
# 3        Batch7                      Gopalpur             2025
# 4        Batch2                      Srinagar             2025
# 5        Batch3                      Jamnagar             2016
# 6        Batch4                        Etawah             2022
# 7        Batch2                       Saharsa             2024
# 8        Batch1         Surendranagar Dudhrej             2022
# 9        Batch4                    Ramagundam             2021
# 10       Batch6                     Kamarhati             2025
# 11       Batch2  Raurkela Industrial Township             2022
# 12       Batch5                  North Dumdum             2023
# 13       Batch5                       Danapur             2018
# 14       Batch2                      Agartala             2025
# 15       Batch3                 Visakhapatnam             2020
# 16       Batch5                     Ghaziabad             2022
# 17       Batch3                       Barasat             2025
# 18       Batch6                     Panchkula             2024
# 19       Batch2                 Muzaffarnagar             2022
# 20       Batch5                        Etawah             2028
# 21       Batch1                        Howrah             2023
# 22       Batch2                      Jamnagar             2022
# 23       Batch3                      Ambattur             2019
# 24       Batch7                     Begusarai             2026
# 25       Batch4                         Patna             2025
# 26       Batch2                        Ongole             2016
# 27       Batch4                      Amravati             2020
# 28       Batch3                          Pune             2016
# 29       Batch1                        Howrah             2016
# 30       Batch6                        Jaipur             2027
# 31       Batch5                         Alwar             2021
# 32       Batch2                      Varanasi             2025
# 33       Batch6                         Salem             2016
# 34       Batch1                        Purnia             2024
# 35       Batch6                       Nandyal             2029
# 36       Batch5                        Karnal             2022
# 37       Batch4                     Hyderabad             2019
# 38       Batch5                         Katni             2018
# 39       Batch6                        Amroha             2018
# 40       Batch2                   Bulandshahr             2026
# 41       Batch3                       Sambhal             2025
# 42       Batch6                   Pudukkottai             2020
# 43       Batch7                       Bellary             2028
# 44       Batch3                        Nanded             2019
# 45       Batch6                      Bareilly             2020
# 46       Batch5                       Bhiwani             2023
# 47       Batch7                   Vasai-Virar             2021
# 48       Batch2                     Tadipatri             2021
# 49       Batch2                    Bhimavaram             2024  , 'programming':                           programming_id  student_id     language  \
# 0   88f413f1-f896-4a5d-a7be-2e36f3068760           1       Python
# 1   6221576f-c5ec-473f-94a7-600a84b17858           2       Pandas
# 2   26b8f58b-9d65-4a50-8ed9-77621ddadaf7           3         Java
# 3   50f132bb-d972-4f35-a406-fb85cb655adf           4       Pandas
# 4   55eec837-f2cc-4deb-8af1-53cf9b8a4079           5  Data Mining
# 5   cc97952b-ab5a-449b-8689-4ce06abe73b4           6         Java
# 6   c5908e86-3a2b-4613-82c1-93ac2d0c7c3d           7   JavaScript
# 7   41016126-c7cc-4325-8674-cf97285d33b8           8       Python
# 8   f39ecd94-168e-48c8-97b0-7f8e9d62dbbd           9           C#
# 9   50ac1738-ee68-4331-8f92-9e6f9dfce0ff          10  Data Mining
# 10  38814e89-510d-44cc-8c17-297af8be149b          11            C
# 11  96653383-3f30-4f16-8149-3d60c70387c7          12            C
# 12  35b7b299-f8e2-488e-a5db-9e80ed3f5750          13       Pandas
# 13  a0606ab3-2881-4801-8dc1-95c606f79c39          14           C#
# 14  255cca14-ecc5-475d-8667-8ad123308c4e          15  Data Mining
# 15  61f10d2b-aeaf-4822-9bed-c1963e3ec7e4          16  Data Mining
# 16  4d94bcd0-e577-4119-a492-930740b8f6ce          17         Java
# 17  8f189063-3c2c-4cd9-b1b1-b144a58d67ff          18       Pandas
# 18  e9003131-62a2-49a0-8595-1a6371396232          19       Python
# 19  34e57ea7-bab1-48d2-b4a2-23ce3656c36f          20            C
# 20  eb09ce5f-8a2f-4ae0-891a-92d0a3e6bf53          21   JavaScript
# 21  819a01ad-4e57-4a7d-ad20-548476d795e1          22        Linux
# 22  7bb78544-e364-4fb6-a19a-3b32158ce00f          23           C#
# 23  54db1e56-2c96-4da4-a469-5b413c818c5a          24          SQL
# 24  950ea6ac-d418-4b52-abe1-f17ebf8da330          25       Pandas
# 25  51b185e1-03f6-4265-8b9d-3bc3599f39d1          26   JavaScript
# 26  9452f08a-30c4-4e0c-8bb7-ebd69569bc16          27          SQL
# 27  9fb3d477-c1cf-4bff-8f38-b9706fda3bae          28         Java
# 28  239aae13-efd2-4bd4-a42f-5f4c39c94ccd          29         Java
# 29  d63b8a2c-e880-4ba7-9350-f602e7ac8f73          30  Data Mining
# 30  141947a3-3827-4300-8608-289a173b05df          31          SQL
# 31  71f6d4fb-058f-41c4-9381-f11b7457e7aa          32   JavaScript
# 32  a726f4d7-51de-49a6-9d18-8d550c8dbb6e          33         Java
# 33  8f06db66-15f4-4a51-9917-e1ee7b4e1865          34  Data Mining
# 34  dc6f89a6-b3c3-44cf-92bd-222463a11eb8          35         Java
# 35  20117d04-8786-44d9-ad63-bc10458d4ca3          36       Python
# 36  83288414-56ae-40df-9cc0-4e4ec56fb87b          37            C
# 37  f971189c-4305-4b49-9374-9df27a94bb56          38   JavaScript
# 38  282e4c3e-4804-49a1-8ed0-792c201c27aa          39          SQL
# 39  90677172-a385-41c7-8a81-7a8ae9350a61          40         Java
# 40  24112671-43e5-4eef-8bda-8b0e9935960d          41          SQL
# 41  95d4536f-465e-4b7f-9812-bb51c9bc366d          42  Data Mining
# 42  4d996d99-6448-4f7d-8e5a-1924b0af3703          43            C
# 43  941c5641-6ad0-4907-ad1f-b1bd862cc711          44           C#
# 44  ba0476b7-6492-4626-b6d7-c1bda2633f24          45           C#
# 45  9ed6b296-a9b8-473a-bce2-4b1a950b5f0c          46          SQL
# 46  37304502-3046-4092-98d0-aa2dd8978db3          47  Data Mining
# 47  f3aa8474-eced-47ef-929f-829cfdf17e58          48   JavaScript
# 48  c2e6a7d9-fd3e-40ee-9426-29acfa7ceecd          49         Java
# 49  9e1038b5-d76b-4622-8a6e-70a0e2019043          50  Data Mining
#
#     problems_solved  assessments_completed  mini_projects  \
# 0               148                      3             15
# 1                59                      8             13
# 2                96                     11              9
# 3                29                      5             28
# 4                42                      5              9
# 5                25                     30              2
# 6                 4                     15             21
# 7                56                      5             16
# 8                16                     26              2
# 9                43                     25             28
# 10               65                      7             20
# 11              131                      8             20
# 12                1                     11              2
# 13               86                     14             14
# 14               90                     14             17
# 15               47                      2             20
# 16              141                      1              8
# 17               60                     28             10
# 18                5                      5              6
# 19               30                     17             26
# 20              124                      2              1
# 21               92                     10              4
# 22              119                      7              0
# 23              139                     16             25
# 24               41                     27              5
# 25               31                     11             14
# 26                2                      2             30
# 27               97                      6             20
# 28               99                     26              0
# 29              105                     25              4
# 30               41                     26             21
# 31               39                     30             13
# 32              141                      1              6
# 33               60                     18              4
# 34               70                      5             15
# 35              131                      4             13
# 36               47                     27             29
# 37              136                     10             16
# 38               19                     23              3
# 39                9                     20             21
# 40              107                     24             20
# 41              100                     10              6
# 42              139                     30             26
# 43               50                     13              2
# 44               70                     18              3
# 45               59                     10             29
# 46               18                     13              6
# 47               42                      7             30
# 48              120                     17             23
# 49               42                     12             29
#
#     certifications_earned  latest_project_score
# 0                      13                   179
# 1                      29                   109
# 2                      17                   133
# 3                      10                    72
# 4                      30                    86
# 5                      22                    79
# 6                       2                    42
# 7                       2                    79
# 8                      25                    69
# 9                       3                    99
# 10                     17                   109
# 11                      1                   160
# 12                      0                    14
# 13                     23                   137
# 14                      9                   130
# 15                     12                    81
# 16                     19                   169
# 17                     15                   113
# 18                      7                    23
# 19                     18                    91
# 20                     26                   153
# 21                      9                   115
# 22                      1                   127
# 23                     11                   191
# 24                      1                    74
# 25                     10                    66
# 26                      4                    38
# 27                      6                   129
# 28                      6                   131
# 29                     13                   147
# 30                     17                   105
# 31                     12                    94
# 32                      3                   151
# 33                      9                    91
# 34                     10                   100
# 35                     16                   164
# 36                     26                   129
# 37                     29                   191
# 38                      2                    47
# 39                     19                    69
# 40                      7                   158
# 41                     19                   135
# 42                     18                   213
# 43                      5                    70
# 44                      5                    96
# 45                     19                   117
# 46                      0                    37
# 47                     22                   101
# 48                     12                   172
# 49                     23                   106  , 'softskills':                            soft_skill_id  student_id  communication  teamwork  \
# 0   2bcefacd-ab90-43d8-a9f3-3348ff380be9           1             65        55
# 1   6e6502d7-658c-408e-88b2-0d4131fa3f8e           2              9        79
# 2   670b93e5-f788-4b29-b8ca-41e801c5f9b8           3             15        66
# 3   a038ea96-8035-46ab-b7bd-dd282d804f32           4             85        65
# 4   2f605333-8739-48c7-b465-6afe8cf8f7ec           5             55        78
# 5   6565f092-ad42-4665-a645-fb676c282a64           6             65        20
# 6   afd3a973-e3f0-4199-b4b4-dd3e71b04cf4           7             39        71
# 7   09acc66e-8f8f-49fb-833c-389191280f7a           8              0        34
# 8   605796a5-0e65-40ea-b75b-37e481ad370b           9             69        84
# 9   3e9eba32-6c0b-4f2f-869d-e49e3a441efd          10             67        59
# 10  321283a7-a39f-472b-9a9e-f52a64c4611a          11             71        30
# 11  da49b0f6-4f34-4181-9f90-40393c486a87          12             98        77
# 12  e58ec569-815f-4760-a48e-f97b0cd39da2          13             49        13
# 13  a605011f-8e32-47c6-92cb-aa91a2b1c99b          14             13        71
# 14  2be7d419-6283-448b-9aed-33ec3c951dbb          15              8        28
# 15  ff246e49-ee6c-4d61-a742-74fd8d9c20dc          16              9        47
# 16  df35babb-a64e-462a-97e1-ff73e86f58d9          17             56         8
# 17  1af27df7-cd13-42f4-a6d1-3abd0f507170          18             85        44
# 18  f5c3abd0-d56d-4156-955e-e3e79ce8b281          19             79        99
# 19  a9698fce-dac8-4918-b062-c0e92a959f0e          20              7        78
# 20  7037aa63-777c-4cf3-bda7-76dd8f55cbfa          21              9        52
# 21  ca5a9c3f-2ef1-4fe5-8dfe-09a7c9fafeca          22             55        33
# 22  74b190d2-d45c-4a03-941e-e0b4a8864072          23             21         0
# 23  f9826a94-176b-49ba-bf54-50addc66bd54          24              5        74
# 24  92414692-2235-41ca-b4e9-55febff0d8af          25              7        36
# 25  7b115e76-ce52-4cce-88c9-963ca7fa72bd          26             40        39
# 26  96f7ae73-9429-4ae7-92c5-564e146ce134          27             16        43
# 27  74782321-7f08-4060-a94c-9e87057280ed          28             46        41
# 28  6fa69f5f-5ac1-4374-ab88-f1d6a2d5f1d0          29             74        74
# 29  6c27eedc-fc47-4ec8-9c8e-132a04302fb9          30             74        52
# 30  213a6520-8987-4a99-b539-3115eb279919          31             31         8
# 31  75f05efa-2195-4bea-becf-9f855b567ccc          32             12        15
# 32  4f82e63e-70e6-4bb3-ae70-fbe0481ec6e1          33             58        88
# 33  7043ce51-7a50-461e-b3c0-1603f3806fb4          34             43        63
# 34  2bddf581-0b28-483a-99fc-cce7bcf3fa28          35             31        94
# 35  03830723-1b58-45ec-bb35-ff2ad0ed6589          36             67        21
# 36  e4a3b91f-9b92-4710-8755-2a68ad83de66          37              6        95
# 37  79e4ba67-f610-47dd-96e0-e606aa745332          38             47        99
# 38  9b3aeadc-a185-49dd-b137-5dc0822980db          39             36        20
# 39  7859b709-045c-411e-85a8-6ef0ce08139f          40             18        44
# 40  fe865ee5-c9de-4a7b-9684-fa0a06638ce2          41             20         2
# 41  2ab3b9ac-c483-4ef1-9ac8-cf655b86d0a3          42             42        30
# 42  65404d6a-2be0-417e-ad9e-0cb59101d7fc          43             64        72
# 43  734c0b1e-d0d9-45a8-9786-8ed58eefb1d1          44             56        17
# 44  db60bdfb-8be1-4210-9ef4-d17ea1425296          45             44        58
# 45  ad130784-d4d4-4ff0-853b-8ab7484b5792          46              0        10
# 46  5bad6a4c-4083-40dc-9ae1-cfedf6b8decd          47             19        15
# 47  569c8582-bc16-4bd7-8f2a-bb3604ffedcf          48             60        32
# 48  5a0be2f4-96a6-4ae5-962e-4d7512335ec6          49             53        54
# 49  c6bca608-1131-40a8-8241-b950759d5a51          50             58        32
#
#     presentation  leadership  critical_thinking  interpersonal_skills
# 0             36          90                 11                    97
# 1             46          51                 45                    90
# 2             38           9                 37                    29
# 3             21          79                 18                    40
# 4             26          56                  2                    28
# 5            100          70                 97                    40
# 6             95         100                 33                    35
# 7              5           7                 86                    20
# 8             94          40                 77                    68
# 9             53          70                 51                    70
# 10             8          92                 84                    27
# 11            18          92                  3                    36
# 12            97          49                 38                     4
# 13            81           0                 67                    97
# 14            56          26                 22                    27
# 15            77          32                 75                    14
# 16            21           7                 40                    47
# 17             1          36                 21                    12
# 18            47          92                 22                    94
# 19            69          48                 57                     5
# 20            95          17                 39                    51
# 21             0           8                 55                     2
# 22            80          62                 62                    67
# 23            44          82                 11                    75
# 24           100          31                 48                    80
# 25             5          11                 41                    35
# 26            38          36                 21                    98
# 27            18          95                 44                    99
# 28            78          83                 74                    64
# 29            91          27                 43                     7
# 30            80          46                 84                    68
# 31            47          21                 78                    55
# 32             4          81                 47                    36
# 33            22          14                 65                     9
# 34             9          75                  2                    38
# 35            86          90                 50                    56
# 36            56          92                 64                    34
# 37             3          26                 77                    80
# 38            29           0                 42                    40
# 39             3          92                 31                    60
# 40            12          34                 85                    53
# 41            55          45                 62                    90
# 42            28          67                 92                    53
# 43            86          60                 40                    81
# 44            20          83                 84                    93
# 45            51          80                 98                    14
# 46            75          27                 54                    29
# 47            56          21                 30                    85
# 48            31          24                  4                    33
# 49            34          76                 84                    94  , 'placements':                             placement_id  student_id  mock_interview_score  \
# 0   cfa292f4-a64c-4414-9cec-86b2499736f1           1                    40
# 1   f88a6246-c979-49c5-a800-2848a2545513           2                    33
# 2   e27c0ab5-6dcf-46cc-9357-951c89c132ef           3                    10
# 3   13a247da-72c6-4690-966b-5d17d622e518           4                    29
# 4   81d6b92a-2c66-41c5-a303-f857121aedbd           5                     5
# 5   9b741f28-291f-4562-8190-761b0cdd8edf           6                    89
# 6   c996ddff-8014-4b34-a232-d245be9770ef           7                    16
# 7   5bc2caf9-8d7f-43c0-ab40-c476757ccd62           8                    79
# 8   a7503ee2-cb20-4318-93c9-5399b7fead45           9                    48
# 9   e60c5861-3214-422a-9758-229d2bc9a73b          10                    17
# 10  14cf5115-dd1a-4ad6-9c29-2149e4d211e0          11                    19
# 11  b36bae9f-1b84-45ba-86f8-317231e8d9a3          12                    69
# 12  27d7cf84-bfbb-4c7b-b118-e9f0c00de3f1          13                    56
# 13  b8309da8-046c-4e2f-bc7f-18eb6363b3a3          14                    36
# 14  32428682-c7c9-4366-a55e-dd56f19a5ff1          15                    21
# 15  828af245-a521-49b1-ad6b-53906af11d6b          16                    96
# 16  a7e50b18-0a0b-42cf-8048-299a44546d8a          17                    93
# 17  4c5b2c9f-a429-4c0f-8162-11f34dd7f42c          18                    59
# 18  c49d9f5e-7b76-4fa7-88d5-2f8632b6f93f          19                    36
# 19  6d69e8d6-6f0d-493b-b71f-b15537c227ac          20                     8
# 20  63048405-002a-4af5-9ef8-7eb81b2f0251          21                    49
# 21  ea026f21-b874-4a85-b347-ac161b68dfe7          22                    83
# 22  6e97cd65-6779-4047-89d9-0b3e7587cb5c          23                    97
# 23  f483891c-c7fa-410b-9df2-a74daa28097c          24                    11
# 24  3c6d71c9-e946-4b4a-91bd-e9c1053a65cd          25                    34
# 25  9c1da362-5f4a-499e-9661-1d5354a7fc32          26                    37
# 26  834e0c52-394a-49c0-b823-5930a1626495          27                    17
# 27  8f2561d5-176c-441f-a46e-558e15986bde          28                    23
# 28  6364cab0-3ed9-418b-b0f8-2f20536be626          29                    11
# 29  b376833a-82fe-4a5c-843d-34feb028e899          30                    85
# 30  19b398d9-9d55-4d9d-9210-e74840c2bf91          31                    88
# 31  6ab2de84-7f45-4acb-a1ed-45cf9e13fa8e          32                    63
# 32  6f1bd169-d79d-46b1-b594-27d1ac35b479          33                    33
# 33  096b0470-5a80-4a3c-8106-ec21a584ecf4          34                    84
# 34  41c0441e-5d99-4cda-bfc8-ee65f66af9b1          35                    42
# 35  c4012838-6cd5-4eab-8447-231fd7247740          36                    74
# 36  1d05d6ef-af63-41ab-83b2-a0d0f3bafc9e          37                    51
# 37  9dd76e04-6dab-4649-bcc9-6f15876ad5d5          38                    11
# 38  6ecda96a-a74f-49bd-8f37-12c54d665840          39                    21
# 39  fef99a5e-dc18-45a9-93f2-e6332ca28293          40                    73
# 40  98b39cbd-cf0e-4495-8c29-ad950ce77efa          41                    33
# 41  0fcf3573-1cc5-4eef-9bf9-bd3d7567eb2a          42                    12
# 42  fa4bb076-b137-4abe-b9e5-c33639201757          43                    38
# 43  5b226bf2-e737-42b6-a66c-6baf0affa307          44                    33
# 44  cdfd2bd1-1f0c-4b87-b971-c62c61757be3          45                    29
# 45  85341292-2c2c-4013-baf5-b71509f0ba76          46                    87
# 46  e382ef5e-060a-4939-b9b6-6c7d164f7583          47                    90
# 47  e9be5a56-15de-47fc-b867-49829ebb68e0          48                    73
# 48  4cd9a213-8757-46be-accf-7618224ccf9f          49                    69
# 49  77387378-9f9f-47c4-815d-050ab6e950e3          50                    24
#
#     internships_completed placement_status  interview_rounds_cleared  \
# 0                      20        Not Ready                         6
# 1                       0        Not Ready                         4
# 2                      12            Ready                         8
# 3                       3            Ready                         9
# 4                       3            Ready                         6
# 5                       4        Not Ready                        19
# 6                       8           Placed                         1
# 7                       2        Not Ready                         6
# 8                       3            Ready                         7
# 9                      11        Not Ready                         8
# 10                      2            Ready                        18
# 11                      1            Ready                         5
# 12                     11            Ready                         6
# 13                     19            Ready                         6
# 14                     13           Placed                         2
# 15                     15           Placed                         2
# 16                      5           Placed                         1
# 17                      4        Not Ready                        11
# 18                     11            Ready                         7
# 19                     18           Placed                        16
# 20                      6        Not Ready                        12
# 21                     10        Not Ready                        16
# 22                     15            Ready                         8
# 23                      9        Not Ready                         4
# 24                     17            Ready                         5
# 25                      2        Not Ready                        18
# 26                     20           Placed                        14
# 27                      8           Placed                        10
# 28                      9            Ready                        11
# 29                     16           Placed                        20
# 30                     15            Ready                         5
# 31                     11        Not Ready                        17
# 32                     13           Placed                        13
# 33                      4           Placed                         8
# 34                      1           Placed                        18
# 35                      0           Placed                        19
# 36                      4           Placed                        13
# 37                     16           Placed                        13
# 38                     14           Placed                        15
# 39                      8           Placed                        15
# 40                     12            Ready                         6
# 41                     13        Not Ready                         1
# 42                     15        Not Ready                         8
# 43                      5        Not Ready                        13
# 44                      4            Ready                        16
# 45                      8           Placed                        11
# 46                     15            Ready                        17
# 47                     13        Not Ready                        12
# 48                      5           Placed                         7
# 49                     19            Ready                        12
#
#    company_name placement_package      placement_date
# 0          None              None                 NaT
# 1          None              None                 NaT
# 2          None              None                 NaT
# 3          None              None                 NaT
# 4          None              None                 NaT
# 5          None              None                 NaT
# 6     Accenture           $ 33023 2024-02-15 16:52:25
# 7          None              None                 NaT
# 8          None              None                 NaT
# 9          None              None                 NaT
# 10         None              None                 NaT
# 11         None              None                 NaT
# 12         None              None                 NaT
# 13         None              None                 NaT
# 14    Capgemini           $ 30839 2024-04-09 22:03:02
# 15         HCL            $ 28792 2022-01-21 18:15:40
# 16       Amazon           $ 44638 2024-07-28 18:43:45
# 17         None              None                 NaT
# 18         None              None                 NaT
# 19    Accenture           $ 46974 2022-08-18 13:30:05
# 20         None              None                 NaT
# 21         None              None                 NaT
# 22         None              None                 NaT
# 23         None              None                 NaT
# 24         None              None                 NaT
# 25         None              None                 NaT
# 26       Amazon           $ 33625 2021-11-06 22:10:35
# 27          TCS           $ 47159 2024-01-20 06:59:20
# 28         None              None                 NaT
# 29       Amazon           $ 45106 2022-03-22 17:45:57
# 30         None              None                 NaT
# 31         None              None                 NaT
# 32          CTS           $ 38100 2021-09-24 21:55:06
# 33          TCS           $ 22431 2021-12-02 13:47:04
# 34          TCS           $ 47052 2024-06-06 11:00:45
# 35         HCL            $ 34017 2021-06-08 18:11:46
# 36          CTS           $ 34927 2023-09-10 11:05:46
# 37    Accenture           $ 45226 2024-01-12 10:00:21
# 38    Capgemini           $ 45602 2022-12-24 12:04:35
# 39         HCL            $ 43164 2020-06-09 23:00:38
# 40         None              None                 NaT
# 41         None              None                 NaT
# 42         None              None                 NaT
# 43         None              None                 NaT
# 44         None              None                 NaT
# 45      INFOSYS           $ 47292 2024-05-06 07:26:31
# 46         None              None                 NaT
# 47         None              None                 NaT
# 48          IBM           $ 46100 2021-12-09 04:05:34
# 49         None              None                 NaT  }

# %%
from sqlalchemy import create_engine

# Setup
engine = create_engine("mysql+mysqlconnector://{user}:{pw}@{host}/{db}".format(host="127.0.0.1", db="placementeligibility", user="root", pw="NewStart2025"))
#customers_df.to_sql('students', engine, if_exists='append', index=False)

# Export students first
try:
    data["students"].to_sql(name="students", con=engine, if_exists="append", index=False)


    print("Sucessfully exported STUDENTS table to MySQL.")

except SQLAlchemyError as e:
    print("Error occurred:", e)

try:
# Export dependent tables
    for table_name in ["programming", "softskills", "placements"]:
        #data[table_name].to_sql(name=table_name, con=engine, if_exists="replace", index=False)
        data[table_name].to_sql(name=table_name, con=engine, if_exists="append", index=False)
        print(f" Sucessfully exported '{table_name}' table to MySQL.")

except SQLAlchemyError as e:
    print("Error occurred:", e)
# Out:
# Sucessfully exported STUDENTS table to MySQL.
#  Sucessfully exported 'programming' table to MySQL.
#  Sucessfully exported 'softskills' table to MySQL.
#  Sucessfully exported 'placements' table to MySQL.
